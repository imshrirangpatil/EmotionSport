# %%
import os
import cv2
import numpy as np
from collections import defaultdict

import scikitplot
import seaborn as sns
from matplotlib import pyplot

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import TimeDistributed, LSTM, Bidirectional
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
# Out:
# Using TensorFlow backend.

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# surprise has 249 number of images
# fear has 75 number of images
# sadness has 84 number of images
# happy has 207 number of images
# anger has 135 number of images

# %% [markdown]
# `sadness` and `fear` has very low number of images as compared to other classes

# %%
TOP_EMOTIONS = ["happy", "surprise", "anger", "sadness", "fear"]

# %% [markdown]
# ### Data Preprocessing
#
# I first make the data compatible for neural nets

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# data

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])

def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]

def img2array(x,path):
    arr = np.empty(shape=(3,48,48))
    for i,f in enumerate(x):
        img = cv2.imread(path+f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())
    data[emotion] = dict((k, img2array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# data

# %%
for k,v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# surprise has 83 samples
# fear has 25 samples
# sadness has 28 samples
# happy has 69 samples
# anger has 45 samples

# %%
surprise = np.stack(data["surprise"].values(), axis=0)
surprise = surprise.reshape(*surprise.shape,1)

happy = np.stack(data["happy"].values(), axis=0)
happy = happy.reshape(*happy.shape,1)

anger = np.stack(data["anger"].values(), axis=0)
anger = anger.reshape(*anger.shape,1)

sadness = np.stack(data["sadness"].values(), axis=0)
sadness = sadness.reshape(*sadness.shape,1)

fear = np.stack(data["fear"].values(), axis=0)
fear = fear.reshape(*fear.shape,1)

X = np.concatenate((surprise, happy, anger, sadness, fear))
y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))
y = np_utils.to_categorical(y)

X.shape, y.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# ((250, 3, 48, 48, 1), (250, 5))

# %%
label_emotion_mapper = {0:"surprise", 1:"happy", 2:"anger", 3:"sadness", 4:"fear"}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, stratify=y, shuffle=True, random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((175, 3, 48, 48, 1), (75, 3, 48, 48, 1))

# %%
np.random.seed(42)
surprise_idx = np.random.choice(np.where(y_train[:, 0]==1)[0], size=1)
happy_idx = np.random.choice(np.where(y_train[:, 1]==1)[0], size=1)
anger_idx = np.random.choice(np.where(y_train[:, 2]==1)[0], size=1)
sad_idx = np.random.choice(np.where(y_train[:, 3]==1)[0], size=1)
fear_idx = np.random.choice(np.where(y_train[:, 4]==1)[0], size=1)

fig = pyplot.figure(1, (6,13))

i = 0
for name, idx in zip(label_emotion_mapper.values(), [surprise_idx, happy_idx, anger_idx, sad_idx, fear_idx]):
    for j in range(3):
        i += 1
        ax = pyplot.subplot(5,3,i)
        sample_img = X_train[idx][0,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(name)

# %%
# data normalization
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
def build_dcnn(input_shape, show_arch=True):
    """
    This is a Deep Convolutional Neural Network (DCNN). For generalization purpose I used dropouts in regular intervals.
    I used `ELU` as the activation because it avoids dying relu problem but also performed well as compared to LeakyRelu
    atleast in this case. `he_normal` kernel initializer is used as it suits ELU. BatchNormalization is also used for better
    results.
    """
    net = Sequential(name='DCNN')

    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            input_shape=input_shape,
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_1'))
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_2'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    net.add(Dropout(0.45, name='dropout_1'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    net.add(Dropout(0.45, name='dropout_2'))

    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_5'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_6'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
    net.add(Dropout(0.4, name='dropout_3'))

    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_7'
        )
    )
    net.add(BatchNormalization(name='batchnorm_7'))
    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_8'
        )
    )
    net.add(BatchNormalization(name='batchnorm_8'))
    
    net.add(Dropout(0.4, name='dropout_4'))
    
    net.add(GlobalMaxPool2D(name="globalmax2d"))
    
    if show_arch:
        net.summary()
    
    return net

# %%
def memory_model(input_shape, num_class, show_arch=True):
    dcnn = build_dcnn(input_shape[1:], show_arch=False)
    
    model = Sequential(name="convolutional_Bidrectional_LSTM")

    model.add(
        TimeDistributed(
            dcnn,
            input_shape=input_shape,
            name="time_distributed",
        )
    )
    
    model.add(Bidirectional(LSTM(128, return_sequences=True, name="bidirect_lstm_1")))
    model.add(Dropout(.35, name="dropout_1"))
    model.add(Bidirectional(LSTM(64, return_sequences=False, name="bidirect_lstm_2")))
    model.add(Dropout(.45, name="dropout_2"))

    model.add(
        Dense(
            128,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    model.add(BatchNormalization(name='batchnorm_1'))
    model.add(Dropout(.7, name="dropout_3"))

    model.add(
        Dense(
            num_class,
            activation='softmax',
            name='out_layer'
        )
    )
    
    if show_arch:
        model.summary()
    
    return model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
#     early_stopping,
    lr_scheduler,
]

batch_size = 32
epochs = 100

# %%
INPUT_SHAPE = (3, 48, 48, 1)
optim = optimizers.Nadam(0.001)

model = memory_model(INPUT_SHAPE, num_class=5)
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)
# Out:
# Model: "convolutional_Bidrectional_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 3, 512)            4691904
# _________________________________________________________________
# bidirectional (Bidirectional (None, 3, 256)            656384
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 5)                 645
# =================================================================
# Total params: 5,530,309
# Trainable params: 5,526,213
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_valid, y_valid),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train on 175 samples, validate on 75 samples
# Epoch 1/100
# 175/175 [==============================] - 13s 77ms/sample - loss: 3.0838 - accuracy: 0.2229 - val_loss: 1.5846 - val_accuracy: 0.2800
# Epoch 2/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.1308 - accuracy: 0.2286 - val_loss: 1.6975 - val_accuracy: 0.1067
# Epoch 3/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.2470 - accuracy: 0.2057 - val_loss: 1.6213 - val_accuracy: 0.1600
# Epoch 4/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.7790 - accuracy: 0.2743 - val_loss: 1.7438 - val_accuracy: 0.1733
# Epoch 5/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4784 - accuracy: 0.2571 - val_loss: 1.6657 - val_accuracy: 0.1733
# Epoch 6/100
# 175/175 [==============================] - 1s 3ms/sample - loss: 2.8926 - accuracy: 0.2400 - val_loss: 1.9171 - val_accuracy: 0.1600
# Epoch 7/100
# 175/175 [==============================] - 1s 3ms/sample - loss: 2.7541 - accuracy: 0.2229 - val_loss: 1.9637 - val_accuracy: 0.1333
# Epoch 8/100
# 160/175 [==========================>...] - ETA: 0s - loss: 2.6259 - accuracy: 0.2688
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6458 - accuracy: 0.2571 - val_loss: 1.9914 - val_accuracy: 0.1067
# Epoch 9/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6590 - accuracy: 0.2114 - val_loss: 2.1048 - val_accuracy: 0.1067
# Epoch 10/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6609 - accuracy: 0.2571 - val_loss: 2.1931 - val_accuracy: 0.1067
# Epoch 11/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6201 - accuracy: 0.2857 - val_loss: 2.3479 - val_accuracy: 0.1067
# Epoch 12/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.2552 - accuracy: 0.3200 - val_loss: 2.3935 - val_accuracy: 0.1067
# Epoch 13/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4324 - accuracy: 0.2743 - val_loss: 2.4428 - val_accuracy: 0.1600
# Epoch 14/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.3782 - accuracy: 0.3086 - val_loss: 2.5352 - val_accuracy: 0.1733
# Epoch 15/100
# 160/175 [==========================>...] - ETA: 0s - loss: 2.2953 - accuracy: 0.3063
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.3248 - accuracy: 0.3029 - val_loss: 2.5071 - val_accuracy: 0.1733
# Epoch 16/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.0065 - accuracy: 0.3657 - val_loss: 2.4804 - val_accuracy: 0.1733
# Epoch 17/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.9556 - accuracy: 0.3771 - val_loss: 2.4382 - val_accuracy: 0.1733
# Epoch 18/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.8205 - accuracy: 0.4171 - val_loss: 2.6489 - val_accuracy: 0.1733
# Epoch 19/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.5699 - accuracy: 0.5086 - val_loss: 2.5568 - val_accuracy: 0.1733
# Epoch 20/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.6782 - accuracy: 0.4400 - val_loss: 2.3823 - val_accuracy: 0.1733
# Epoch 21/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.3725 - accuracy: 0.5486 - val_loss: 2.2674 - val_accuracy: 0.1867
# Epoch 22/100
# 160/175 [==========================>...] - ETA: 0s - loss: 1.1726 - accuracy: 0.6125
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.1785 - accuracy: 0.6229 - val_loss: 2.0988 - val_accuracy: 0.2267
# Epoch 23/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0398 - accuracy: 0.6000 - val_loss: 2.4250 - val_accuracy: 0.2267
# Epoch 24/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0922 - accuracy: 0.6343 - val_loss: 1.9578 - val_accuracy: 0.2400
# Epoch 25/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0385 - accuracy: 0.6857 - val_loss: 2.0699 - val_accuracy: 0.3067
# Epoch 26/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2000 - accuracy: 0.6457 - val_loss: 2.2186 - val_accuracy: 0.3200
# Epoch 27/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2499 - accuracy: 0.6343 - val_loss: 2.1176 - val_accuracy: 0.2667
# Epoch 28/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9510 - accuracy: 0.6857 - val_loss: 2.2317 - val_accuracy: 0.3200
# Epoch 29/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8131 - accuracy: 0.7314 - val_loss: 1.5762 - val_accuracy: 0.5067
# Epoch 30/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8044 - accuracy: 0.7143 - val_loss: 1.3446 - val_accuracy: 0.5333
# Epoch 31/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9277 - accuracy: 0.7086 - val_loss: 1.1771 - val_accuracy: 0.5733
# Epoch 32/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7852 - accuracy: 0.7200 - val_loss: 1.2971 - val_accuracy: 0.6000
# Epoch 33/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8286 - accuracy: 0.7257 - val_loss: 1.1528 - val_accuracy: 0.6133
# Epoch 34/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9292 - accuracy: 0.6857 - val_loss: 1.2875 - val_accuracy: 0.5867
# Epoch 35/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7997 - accuracy: 0.7429 - val_loss: 1.1110 - val_accuracy: 0.6533
# Epoch 36/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7819 - accuracy: 0.7143 - val_loss: 1.0041 - val_accuracy: 0.6533
# Epoch 37/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6032 - accuracy: 0.7657 - val_loss: 0.6971 - val_accuracy: 0.7467
# Epoch 38/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8300 - accuracy: 0.6971 - val_loss: 0.7949 - val_accuracy: 0.7333
# Epoch 39/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7047 - accuracy: 0.7657 - val_loss: 0.8801 - val_accuracy: 0.6933
# Epoch 40/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8461 - accuracy: 0.7371 - val_loss: 0.7432 - val_accuracy: 0.7333
# Epoch 41/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7071 - accuracy: 0.7314 - val_loss: 0.9951 - val_accuracy: 0.6533
# Epoch 42/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6124 - accuracy: 0.7714 - val_loss: 0.9251 - val_accuracy: 0.7200
# Epoch 43/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5844 - accuracy: 0.7771 - val_loss: 0.8846 - val_accuracy: 0.7200
# Epoch 44/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.7347 - accuracy: 0.7812
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7120 - accuracy: 0.7829 - val_loss: 0.8351 - val_accuracy: 0.7200
# Epoch 45/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7819 - accuracy: 0.7029 - val_loss: 0.7642 - val_accuracy: 0.7333
# Epoch 46/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6116 - accuracy: 0.7657 - val_loss: 1.0526 - val_accuracy: 0.6533
# Epoch 47/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6913 - accuracy: 0.7486 - val_loss: 0.8746 - val_accuracy: 0.7200
# Epoch 48/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6982 - accuracy: 0.7486 - val_loss: 0.8284 - val_accuracy: 0.7200
# Epoch 49/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5917 - accuracy: 0.7543 - val_loss: 0.7983 - val_accuracy: 0.7333
# Epoch 50/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7697 - accuracy: 0.6971 - val_loss: 0.8520 - val_accuracy: 0.7067
# Epoch 51/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.6430 - accuracy: 0.7812
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6569 - accuracy: 0.7657 - val_loss: 0.8344 - val_accuracy: 0.7333
# Epoch 52/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6021 - accuracy: 0.7714 - val_loss: 0.8576 - val_accuracy: 0.7333
# Epoch 53/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6217 - accuracy: 0.7543 - val_loss: 0.9240 - val_accuracy: 0.6800
# Epoch 54/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5174 - accuracy: 0.7771 - val_loss: 0.7749 - val_accuracy: 0.7467
# Epoch 55/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5780 - accuracy: 0.7486 - val_loss: 0.7312 - val_accuracy: 0.7600
# Epoch 56/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5465 - accuracy: 0.7600 - val_loss: 0.6331 - val_accuracy: 0.7600
# Epoch 57/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5117 - accuracy: 0.8229 - val_loss: 0.6480 - val_accuracy: 0.7867
# Epoch 58/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5458 - accuracy: 0.8000 - val_loss: 0.6057 - val_accuracy: 0.7600
# Epoch 59/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6038 - accuracy: 0.7657 - val_loss: 0.6721 - val_accuracy: 0.7467
# Epoch 60/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5190 - accuracy: 0.7943 - val_loss: 0.6703 - val_accuracy: 0.7600
# Epoch 61/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5102 - accuracy: 0.7657 - val_loss: 0.6072 - val_accuracy: 0.7600
# Epoch 62/100
# 175/175 [==============================] - 0s 3ms/sample - loss: 0.4557 - accuracy: 0.7886 - val_loss: 0.6354 - val_accuracy: 0.7467
# Epoch 63/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5649 - accuracy: 0.8000 - val_loss: 0.5452 - val_accuracy: 0.7733
# Epoch 64/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5095 - accuracy: 0.7886 - val_loss: 0.5148 - val_accuracy: 0.8000
# Epoch 65/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5877 - accuracy: 0.7600 - val_loss: 0.6228 - val_accuracy: 0.7733
# Epoch 66/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4360 - accuracy: 0.8171 - val_loss: 0.6613 - val_accuracy: 0.7733
# Epoch 67/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4418 - accuracy: 0.8000 - val_loss: 0.6120 - val_accuracy: 0.7733
# Epoch 68/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4909 - accuracy: 0.8000 - val_loss: 0.6210 - val_accuracy: 0.8000
# Epoch 69/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4901 - accuracy: 0.8286 - val_loss: 0.6299 - val_accuracy: 0.8000
# Epoch 70/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4503 - accuracy: 0.8114 - val_loss: 0.5571 - val_accuracy: 0.8000
# Epoch 71/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.4262 - accuracy: 0.8562
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4352 - accuracy: 0.8571 - val_loss: 0.5625 - val_accuracy: 0.7867
# Epoch 72/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4616 - accuracy: 0.8171 - val_loss: 0.5894 - val_accuracy: 0.8000
# Epoch 73/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4912 - accuracy: 0.7886 - val_loss: 0.6106 - val_accuracy: 0.7733
# Epoch 74/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4355 - accuracy: 0.8114 - val_loss: 0.5797 - val_accuracy: 0.8133
# Epoch 75/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4222 - accuracy: 0.8057 - val_loss: 0.5688 - val_accuracy: 0.7867
# Epoch 76/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3509 - accuracy: 0.8514 - val_loss: 0.5654 - val_accuracy: 0.7867
# Epoch 77/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4053 - accuracy: 0.8400 - val_loss: 0.5496 - val_accuracy: 0.7867
# Epoch 78/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3457 - accuracy: 0.8571 - val_loss: 0.5811 - val_accuracy: 0.7867
# Epoch 79/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4803 - accuracy: 0.8286 - val_loss: 0.4985 - val_accuracy: 0.8133
# Epoch 80/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4680 - accuracy: 0.8171 - val_loss: 0.5028 - val_accuracy: 0.8267
# Epoch 81/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3847 - accuracy: 0.8686 - val_loss: 0.5162 - val_accuracy: 0.8133
# Epoch 82/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4358 - accuracy: 0.8171 - val_loss: 0.4721 - val_accuracy: 0.8000
# Epoch 83/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2914 - accuracy: 0.9029 - val_loss: 0.4729 - val_accuracy: 0.8267
# Epoch 84/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3644 - accuracy: 0.8629 - val_loss: 0.6533 - val_accuracy: 0.7867
# Epoch 85/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3559 - accuracy: 0.8571 - val_loss: 0.6247 - val_accuracy: 0.7867
# Epoch 86/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5431 - accuracy: 0.8171 - val_loss: 0.5241 - val_accuracy: 0.7867
# Epoch 87/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.4131 - accuracy: 0.7875
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4472 - accuracy: 0.7714 - val_loss: 0.5086 - val_accuracy: 0.8000
# Epoch 88/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3422 - accuracy: 0.8286 - val_loss: 0.5448 - val_accuracy: 0.7867
# Epoch 89/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3262 - accuracy: 0.8800 - val_loss: 0.6287 - val_accuracy: 0.7733
# Epoch 90/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3241 - accuracy: 0.8571 - val_loss: 0.7080 - val_accuracy: 0.8000
# Epoch 91/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3390 - accuracy: 0.8629 - val_loss: 0.6863 - val_accuracy: 0.7867
# Epoch 92/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3270 - accuracy: 0.8686 - val_loss: 0.6508 - val_accuracy: 0.7733
# Epoch 93/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2466 - accuracy: 0.9086 - val_loss: 0.6310 - val_accuracy: 0.7867
# Epoch 94/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.3175 - accuracy: 0.8438
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3077 - accuracy: 0.8514 - val_loss: 0.6216 - val_accuracy: 0.7733
# Epoch 95/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3341 - accuracy: 0.8857 - val_loss: 0.5594 - val_accuracy: 0.8133
# Epoch 96/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3141 - accuracy: 0.8571 - val_loss: 0.5568 - val_accuracy: 0.7867
# Epoch 97/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2922 - accuracy: 0.8686 - val_loss: 0.5605 - val_accuracy: 0.7867
# Epoch 98/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3573 - accuracy: 0.8629 - val_loss: 0.5467 - val_accuracy: 0.8133
# Epoch 99/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2966 - accuracy: 0.9086 - val_loss: 0.5109 - val_accuracy: 0.8133
# Epoch 100/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3243 - accuracy: 0.8571 - val_loss: 0.4851 - val_accuracy: 0.8000

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.savefig('epoch_history.png')
pyplot.show()

# %% [markdown]
# `The fluctuations in the epoch metrics is due to the fact that we have very low data for such a complex task.`

# %%
yhat_valid = model.predict_classes(X_valid)
scikitplot.metrics.plot_confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid, figsize=(7,7))
pyplot.savefig("confusion_matrix.png")

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid))
# Out:
# total wrong validation predictions: 15
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        25
#            1       0.95      0.90      0.93        21
#            2       0.57      1.00      0.72        13
#            3       0.00      0.00      0.00         8
#            4       0.75      0.75      0.75         8
#
#     accuracy                           0.80        75
#    macro avg       0.65      0.71      0.67        75
# weighted avg       0.78      0.80      0.78        75

# %% [markdown]
# `If we have more data to train then we will get better and more generalized model.`

# %%
np.random.seed(0)
indices = np.random.choice(range(X_valid.shape[0]), size=15, replace=False)

fig = pyplot.figure(1, (9,30))

i = 0
for idx in indices:
    true_emotion = label_emotion_mapper[np.argmax(y_valid[idx])]
    pred_emotion = label_emotion_mapper[model.predict_classes(np.expand_dims(X_valid[idx], axis=0))[0]]
    
    for j in range(3):
        i += 1
        ax = pyplot.subplot(15,3,i)
        sample_img = X_valid[idx,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:{true_emotion}, p:{pred_emotion}")
