# %%
import os
import cv2
import numpy as np
from collections import defaultdict

import scikitplot
import seaborn as sns
from matplotlib import pyplot

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling3D, GlobalMaxPool3D
from tensorflow.keras.layers import TimeDistributed, LSTM, Bidirectional, ConvLSTM2D
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
# Out:
# Using TensorFlow backend.

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# surprise has 249 number of images
# fear has 75 number of images
# sadness has 84 number of images
# happy has 207 number of images
# anger has 135 number of images

# %% [markdown]
# `sadness` and `fear` has very low number of images as compared to other classes

# %%
TOP_EMOTIONS = ["happy", "surprise", "anger", "sadness", "fear"]

# %% [markdown]
# ### Data Preprocessing
#
# I first make the data compatible for the model.

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# data

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])

def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]

def img2array(x,path):
    arr = np.empty(shape=(3,48,48))
    for i,f in enumerate(x):
        img = cv2.imread(path+f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())
    data[emotion] = dict((k, img2array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# data

# %%
for k,v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# surprise has 83 samples
# fear has 25 samples
# sadness has 28 samples
# happy has 69 samples
# anger has 45 samples

# %%
surprise = np.stack(data["surprise"].values(), axis=0)
surprise = surprise.reshape(*surprise.shape,1)

happy = np.stack(data["happy"].values(), axis=0)
happy = happy.reshape(*happy.shape,1)

anger = np.stack(data["anger"].values(), axis=0)
anger = anger.reshape(*anger.shape,1)

sadness = np.stack(data["sadness"].values(), axis=0)
sadness = sadness.reshape(*sadness.shape,1)

fear = np.stack(data["fear"].values(), axis=0)
fear = fear.reshape(*fear.shape,1)

X = np.concatenate((surprise, happy, anger, sadness, fear))
y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))

# X = np.concatenate((surprise, happy, anger, sadness, fear, surprise, happy, anger, sadness, fear))
# y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25), np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))

y = np_utils.to_categorical(y)

X.shape, y.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# ((250, 3, 48, 48, 1), (250, 5))

# %%
label_emotion_mapper = {0:"surprise", 1:"happy", 2:"anger", 3:"sadness", 4:"fear"}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, shuffle=True, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((200, 3, 48, 48, 1), (50, 3, 48, 48, 1))

# %%
np.random.seed(42)
surprise_idx = np.random.choice(np.where(y_train[:, 0]==1)[0], size=1)
happy_idx = np.random.choice(np.where(y_train[:, 1]==1)[0], size=1)
anger_idx = np.random.choice(np.where(y_train[:, 2]==1)[0], size=1)
sad_idx = np.random.choice(np.where(y_train[:, 3]==1)[0], size=1)
fear_idx = np.random.choice(np.where(y_train[:, 4]==1)[0], size=1)

fig = pyplot.figure(1, (6,13))

i = 0
for name, idx in zip(label_emotion_mapper.values(), [surprise_idx, happy_idx, anger_idx, sad_idx, fear_idx]):
    for j in range(3):
        i += 1
        ax = pyplot.subplot(5,3,i)
        sample_img = X_train[idx][0,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(name)

# %%
# data normalization
X_train = X_train / 255.
X_test = X_test / 255.

# %%
def build_convlstm(input_shape, num_class, show_summary=True):
    net = Sequential(name='ConvLSTM2D')

    net.add(
        ConvLSTM2D(
            filters=64,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_1'))
    net.add(
        ConvLSTM2D(
            filters=64,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_2'))

    net.add(
        MaxPooling3D(
            pool_size=(1, 2, 2),
            padding='same',
            name='maxpool3d_1'
        )
    )
    net.add(Dropout(0.3, name='dropout_1'))

    net.add(
        ConvLSTM2D(
            filters=128,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        ConvLSTM2D(
            filters=128,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))

    net.add(
        MaxPooling3D(
            pool_size=(1, 2, 2),
            padding='same',
            name='maxpool3d_2'
        )
    )
    net.add(Dropout(0.3, name='dropout_2'))

    net.add(
        ConvLSTM2D(
            filters=256,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_5'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        ConvLSTM2D(
            filters=256,
            kernel_size=(3,3),
            input_shape=input_shape,
            return_sequences=True,
            recurrent_activation='hard_sigmoid',
            activation='tanh',
            padding='same',
            kernel_initializer='glorot_uniform',
            name='convlstm2d_6'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))

    net.add(
        MaxPooling3D(
            pool_size=(1, 2, 2),
            padding='same',
            name='maxpool3d_3'
        )
    )
    net.add(Dropout(0.3, name='dropout_3'))
    
    net.add(TimeDistributed(Flatten(name="flatten")))
    
    net.add(
        TimeDistributed(
            Dense(
                64,
                activation='elu',
                kernel_initializer='he_normal',
                name='dense_1'
            )
        )
    )
    net.add(BatchNormalization(name='batchnorm_7'))
    net.add(Dropout(.6, name="dropout_4"))

    net.add(
        TimeDistributed(
            Dense(
                num_class,
                activation='softmax',
                name='out_layer'
            )
        )
    )

    if show_summary:
        net.summary()

    return net

# %%
y_train_ = np.empty((y_train.shape[0], 3, 5))
for i in range(y_train.shape[0]):
    y_train_[i] = np.tile(y_train[i], (3,1))
    
y_test_ = np.empty((y_test.shape[0], 3, 5))
for i in range(y_test.shape[0]):
    y_test_[i] = np.tile(y_test[i], (3,1))

# %%
y_train_.shape, y_test_.shape
# Out:
# ((200, 3, 5), (50, 3, 5))

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
#     early_stopping,
    lr_scheduler,
]

batch_size = 8
epochs = 60

# %%
INPUT_SHAPE = (3, 48, 48, 1)
optim = optimizers.Adam(0.001)

model = build_convlstm(INPUT_SHAPE, num_class=5, show_summary=False)
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)

# %%
history = model.fit(
    x=X_train,
    y=y_train_,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/60
# 160/160 [==============================] - 16s 98ms/sample - loss: 2.1936 - accuracy: 0.3375 - val_loss: 1.5094 - val_accuracy: 0.3583
# Epoch 2/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 1.3074 - accuracy: 0.5750 - val_loss: 1.4897 - val_accuracy: 0.4500
# Epoch 3/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 1.0019 - accuracy: 0.6521 - val_loss: 1.6462 - val_accuracy: 0.1500
# Epoch 4/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.9340 - accuracy: 0.6917 - val_loss: 2.1021 - val_accuracy: 0.1583
# Epoch 5/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.7512 - accuracy: 0.7250 - val_loss: 2.2624 - val_accuracy: 0.1583
# Epoch 6/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.7390 - accuracy: 0.7396 - val_loss: 2.0720 - val_accuracy: 0.1583
# Epoch 7/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.5912 - accuracy: 0.7812 - val_loss: 1.6778 - val_accuracy: 0.2750
# Epoch 8/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.4521 - accuracy: 0.8313 - val_loss: 1.4678 - val_accuracy: 0.3917
# Epoch 9/60
# 152/160 [===========================>..] - ETA: 0s - loss: 0.3276 - accuracy: 0.8969
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.3374 - accuracy: 0.8938 - val_loss: 1.5337 - val_accuracy: 0.1667
# Epoch 10/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.2769 - accuracy: 0.9104 - val_loss: 1.6712 - val_accuracy: 0.1583
# Epoch 11/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.2487 - accuracy: 0.9167 - val_loss: 1.8217 - val_accuracy: 0.1417
# Epoch 12/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.2250 - accuracy: 0.9271 - val_loss: 1.9444 - val_accuracy: 0.0917
# Epoch 13/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1678 - accuracy: 0.9521 - val_loss: 2.1712 - val_accuracy: 0.0917
# Epoch 14/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1503 - accuracy: 0.9708 - val_loss: 2.6777 - val_accuracy: 0.1417
# Epoch 15/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1378 - accuracy: 0.9667 - val_loss: 3.0771 - val_accuracy: 0.1583
# Epoch 16/60
# 152/160 [===========================>..] - ETA: 0s - loss: 0.1629 - accuracy: 0.9605
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1986 - accuracy: 0.9542 - val_loss: 2.9327 - val_accuracy: 0.2250
# Epoch 17/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1300 - accuracy: 0.9688 - val_loss: 2.4090 - val_accuracy: 0.1333
# Epoch 18/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1543 - accuracy: 0.9604 - val_loss: 2.5696 - val_accuracy: 0.2417
# Epoch 19/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1024 - accuracy: 0.9812 - val_loss: 2.1602 - val_accuracy: 0.2000
# Epoch 20/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1435 - accuracy: 0.9521 - val_loss: 2.0385 - val_accuracy: 0.3583
# Epoch 21/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1310 - accuracy: 0.9625 - val_loss: 1.8687 - val_accuracy: 0.4000
# Epoch 22/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1801 - accuracy: 0.9604 - val_loss: 1.5453 - val_accuracy: 0.4333
# Epoch 23/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1298 - accuracy: 0.9708 - val_loss: 1.5066 - val_accuracy: 0.4667
# Epoch 24/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1234 - accuracy: 0.9667 - val_loss: 1.3118 - val_accuracy: 0.5250
# Epoch 25/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1500 - accuracy: 0.9583 - val_loss: 1.3558 - val_accuracy: 0.5750
# Epoch 26/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1166 - accuracy: 0.9771 - val_loss: 1.0928 - val_accuracy: 0.5750
# Epoch 27/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0788 - accuracy: 0.9875 - val_loss: 0.8816 - val_accuracy: 0.6667
# Epoch 28/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1080 - accuracy: 0.9750 - val_loss: 0.7139 - val_accuracy: 0.7000
# Epoch 29/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0818 - accuracy: 0.9854 - val_loss: 0.6042 - val_accuracy: 0.7750
# Epoch 30/60
# 160/160 [==============================] - 3s 16ms/sample - loss: 0.0688 - accuracy: 0.9917 - val_loss: 0.4836 - val_accuracy: 0.7917
# Epoch 31/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1071 - accuracy: 0.9771 - val_loss: 0.4247 - val_accuracy: 0.8333
# Epoch 32/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1144 - accuracy: 0.9667 - val_loss: 0.4207 - val_accuracy: 0.8250
# Epoch 33/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0831 - accuracy: 0.9771 - val_loss: 0.3583 - val_accuracy: 0.8750
# Epoch 34/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0872 - accuracy: 0.9812 - val_loss: 0.4030 - val_accuracy: 0.8167
# Epoch 35/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0794 - accuracy: 0.9875 - val_loss: 0.2161 - val_accuracy: 0.9250
# Epoch 36/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0824 - accuracy: 0.9771 - val_loss: 0.3472 - val_accuracy: 0.8750
# Epoch 37/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0867 - accuracy: 0.9792 - val_loss: 0.2751 - val_accuracy: 0.9000
# Epoch 38/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1137 - accuracy: 0.9750 - val_loss: 0.2710 - val_accuracy: 0.9250
# Epoch 39/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0854 - accuracy: 0.9833 - val_loss: 0.1713 - val_accuracy: 0.9417
# Epoch 40/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0732 - accuracy: 0.9896 - val_loss: 0.1616 - val_accuracy: 0.9417
# Epoch 41/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0592 - accuracy: 0.9896 - val_loss: 0.1616 - val_accuracy: 0.9333
# Epoch 42/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0686 - accuracy: 0.9896 - val_loss: 0.1718 - val_accuracy: 0.9333
# Epoch 43/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0489 - accuracy: 0.9958 - val_loss: 0.1638 - val_accuracy: 0.9500
# Epoch 44/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0743 - accuracy: 0.9854 - val_loss: 0.1712 - val_accuracy: 0.9500
# Epoch 45/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.1192 - accuracy: 0.9750 - val_loss: 0.2581 - val_accuracy: 0.9083
# Epoch 46/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0576 - accuracy: 0.9896 - val_loss: 0.2492 - val_accuracy: 0.9167
# Epoch 47/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0570 - accuracy: 0.9917 - val_loss: 0.2092 - val_accuracy: 0.9167
# Epoch 48/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0829 - accuracy: 0.9812 - val_loss: 0.2551 - val_accuracy: 0.9250
# Epoch 49/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0640 - accuracy: 0.9896 - val_loss: 0.2651 - val_accuracy: 0.9167
# Epoch 50/60
# 152/160 [===========================>..] - ETA: 0s - loss: 0.0551 - accuracy: 0.9868
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0536 - accuracy: 0.9875 - val_loss: 0.2864 - val_accuracy: 0.9083
# Epoch 51/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0731 - accuracy: 0.9812 - val_loss: 0.2650 - val_accuracy: 0.9167
# Epoch 52/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0376 - accuracy: 0.9937 - val_loss: 0.2601 - val_accuracy: 0.9083
# Epoch 53/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0939 - accuracy: 0.9875 - val_loss: 0.2860 - val_accuracy: 0.9083
# Epoch 54/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0544 - accuracy: 0.9937 - val_loss: 0.3041 - val_accuracy: 0.8917
# Epoch 55/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0426 - accuracy: 0.9979 - val_loss: 0.2561 - val_accuracy: 0.9000
# Epoch 56/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0527 - accuracy: 0.9896 - val_loss: 0.2938 - val_accuracy: 0.8750
# Epoch 57/60
# 152/160 [===========================>..] - ETA: 0s - loss: 0.0408 - accuracy: 0.9934
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0422 - accuracy: 0.9937 - val_loss: 0.2804 - val_accuracy: 0.8917
# Epoch 58/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0866 - accuracy: 0.9896 - val_loss: 0.2474 - val_accuracy: 0.9167
# Epoch 59/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0474 - accuracy: 0.9937 - val_loss: 0.2252 - val_accuracy: 0.9167
# Epoch 60/60
# 160/160 [==============================] - 2s 15ms/sample - loss: 0.0609 - accuracy: 0.9917 - val_loss: 0.2264 - val_accuracy: 0.9167

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.savefig('epoch_history.png')
pyplot.show()
